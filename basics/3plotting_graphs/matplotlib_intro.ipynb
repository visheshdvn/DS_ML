# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = range(1,4)
y = range(2,8,2)

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# Line graph

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Combining 2 graphs

# %%
plt.scatter(x, y)
plt.plot(x, y)
plt.show()

# %%
x2 = [3, 4, 5]
y2 = [2, 4, 6]

# in the third argument "xy", x determines the color of the line and y determines the style (dot, dash, line etc) of the
plt.plot(x2, y2, "b--")
plt.plot(x, y)
plt.show()

# %%
# plot function x**3
# x = np.array([1, 2, 3, 4])
x = np.arange(0, 5, 0.1)
y = x**3
plt.plot(x, y)
plt.show()
